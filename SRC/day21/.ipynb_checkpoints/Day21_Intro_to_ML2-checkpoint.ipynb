# %% [markdown]
# # Day 21 — Introduction to Machine Learning Categories
#
# ## Definitions
#
# ### Supervised Learning
# Supervised learning is a type of machine learning where the model is trained using labeled data, meaning each input has a known correct output. The algorithm learns the relationship between inputs and outputs so it can predict answers for new, unseen data. It is commonly used for classification and regression problems.
#
# ### Unsupervised Learning
# Unsupervised learning works with unlabeled data, where no correct answers are provided. The model tries to discover hidden patterns, structures, or clusters in the data on its own. It is often used for grouping similar items, customer segmentation, and anomaly detection.
#
# ### Reinforcement Learning
# Reinforcement learning is a method where an agent learns by interacting with an environment and receiving rewards or penalties for its actions. Over time, it improves its strategy to maximize the total reward. This approach is used in robotics, gaming AI, and autonomous decision-making systems.
#
# ---
#
# ## Comparison Table
#
# | ML Type | Key Idea | Example 1 | Example 2 | Example 3 |
# |--------|----------|-----------|-----------|-----------|
# | **Supervised Learning** | Learn from labeled data (input → correct answer) | Spam Email Detection | House Price Prediction | Handwritten Digit Recognition |
# | **Unsupervised Learning** | Find hidden patterns in unlabeled data | Customer Segmentation | Grouping similar news articles | Detecting unusual network activity |
# | **Reinforcement Learning** | Learn via rewards and penalties | Chess/Go playing AI | Self-driving car decisions | Robot learning to walk |
#
# ---
